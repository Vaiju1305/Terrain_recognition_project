# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
model = tf.keras.models.load_model('terrain_recognition_model.h5')

# %%
img_path = "C:/Users/Karan/Desktop/Images/Marshy (16)_10_26.png"

# %%
def plot_image(img_path):
    img = mpimg.imread(img_path)
    plt.imshow(img)
    plt.axis('off')  # Turn off axis
    plt.show()

# %%
#produces image array
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    return img_array

# %%
def predict_terrain(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)
    terrain_categories = ['Grassy', 'Marshy', 'Rocky', 'Sandy']
    predicted_category = terrain_categories[np.argmax(prediction)]
    plot_image(img_path)
    return predicted_category

# %%
preprocess_image(img_path)
# Out:
# array([[[[0.33333334, 0.36862746, 0.2627451 ],
#          [0.34509805, 0.36862746, 0.23529412],
#          [0.29803923, 0.30588236, 0.15294118],
#          ...,
#          [0.13333334, 0.1764706 , 0.11372549],
#          [0.12941177, 0.1764706 , 0.12156863],
#          [0.12941177, 0.18431373, 0.1254902 ]],
#
#         [[0.2901961 , 0.3254902 , 0.21960784],
#          [0.31764707, 0.3372549 , 0.21176471],
#          [0.26666668, 0.27450982, 0.12941177],
#          ...,
#          [0.11764706, 0.16470589, 0.10980392],
#          [0.1254902 , 0.17254902, 0.11764706],
#          [0.1254902 , 0.18039216, 0.12156863]],
#
#         [[0.23529412, 0.2784314 , 0.16078432],
#          [0.26666668, 0.28627452, 0.16078432],
#          [0.29411766, 0.3019608 , 0.15686275],
#          ...,
#          [0.10588235, 0.15294118, 0.09803922],
#          [0.12156863, 0.16862746, 0.11372549],
#          [0.12156863, 0.1764706 , 0.11764706]],
#
#         ...,
#
#         [[0.12156863, 0.19607843, 0.12156863],
#          [0.11764706, 0.19215687, 0.11764706],
#          [0.11372549, 0.18039216, 0.10980392],
#          ...,
#          [0.11764706, 0.16078432, 0.10588235],
#          [0.11372549, 0.15686275, 0.09411765],
#          [0.12156863, 0.15294118, 0.09411765]],
#
#         [[0.12941177, 0.20392157, 0.12941177],
#          [0.12156863, 0.1882353 , 0.11764706],
#          [0.11764706, 0.18431373, 0.11372549],
#          ...,
#          [0.11764706, 0.16078432, 0.09803922],
#          [0.1254902 , 0.15686275, 0.09803922],
#          [0.12156863, 0.15294118, 0.09411765]],
#
#         [[0.13725491, 0.20392157, 0.14117648],
#          [0.13333334, 0.2       , 0.12941177],
#          [0.12941177, 0.19607843, 0.1254902 ],
#          ...,
#          [0.12941177, 0.16078432, 0.10196079],
#          [0.1254902 , 0.15686275, 0.09803922],
#          [0.12156863, 0.15294118, 0.09411765]]]], dtype=float32)

# %%
predicted_category = predict_terrain(img_path)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
print('Predicted terrain category:', predicted_category)
# Out:
# Predicted terrain category: Marshy
